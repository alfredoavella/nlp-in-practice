# %% [markdown]
# <a href="https://colab.research.google.com/github/alfredoavella/nlp-in-practice/blob/master/CancionProtesta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting started with Word2Vec in Gensim and making it work!
#
# The idea behind Word2Vec is pretty simple. We are making and assumption that you can tell the meaning of a word by the company it keeps. This is analogous to the saying *show me your friends, and I'll tell who you are*. So if you have two words that have very similar neighbors (i.e. the usage context is about the same), then these words are probably quite similar in meaning or are at least highly related. For example, the words `shocked`,`appalled` and `astonished` are typically used in a similar context.
#
# In this tutorial, you will learn how to use the Gensim implementation of Word2Vec and actually get it to work! I have heard a lot of complaints about poor performance etc, but its really a combination of two things, (1) your input data and (2) your parameter settings. Note that the training algorithms in this package were ported from the [original Word2Vec implementation by Google](https://arxiv.org/pdf/1301.3781.pdf) and extended with additional functionality.

# %% [markdown]
# ### Imports and logging
#
# First, we start with our imports and get logging established:

# %%
# imports needed and set up logging
import gzip
import gensim 
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ### Dataset
# Next, is our dataset. The secret to getting Word2Vec really working for you is to have lots and lots of text data. In this case I am going to use data from the [OpinRank](http://kavita-ganesan.com/entity-ranking-data/) dataset. This dataset has full user reviews of cars and hotels. I have specifically concatenated all of the hotel reviews into one big file which is about 97MB compressed and 229MB uncompressed. We will use the compressed file for this tutorial. Each line in this file represents a hotel review. You can download the OpinRank Word2Vec dataset here.
#
# To avoid confusion, while gensim’s word2vec tutorial says that you need to pass it a sequence of sentences as its input, you can always pass it a whole review as a sentence (i.e. a much larger size of text), and it should not make much of a difference.
#
# Now, let's take a closer look at this data below by printing the first line. You can see that this is a pretty hefty review.

# %%
data_file="canciones.csv"

with open ('canciones.csv', 'rb') as f:
    for i,line in enumerate (f):
        print(line)
        break
# Out:
# b'ID;Interprete ;Fecha menci\xf3n o  interpretaci\xf3n en p\xfablico;Pa\xeds origen;lugar del evento;autor de la letra o lirica de la canci\xf3n ;Arreglista;Musicalizaci\xf3n;Grabaci\xf3n;Canci\xf3n;referencia, ver en ;Letra en espa\xf1ol ;letra en ingl\xe9s u otro idioma;Otros;opini\xf3n autor a.avella;palabras claves del socialismo;\r\n'

# %% [markdown]
# ### Read files into a list
# Now that we've had a sneak peak of our dataset, we can read it into a list so that we can pass this on to the Word2Vec model. Notice in the code below, that I am directly reading the
# compressed file. I'm also doing a mild pre-processing of the reviews using `gensim.utils.simple_preprocess (line)`. This does some basic pre-processing such as tokenization, lowercasing, etc and returns back a list of tokens (words). Documentation of this pre-processing method can be found on the official [Gensim documentation site](https://radimrehurek.com/gensim/utils.html).

# %%
def read_input(input_file):
    """This method reads the input file which is in gzip format"""
    
    logging.info("reading file {0}...this may take a while".format(input_file))
    
    with open (input_file, 'rb') as f:
        for i, line in enumerate (f): 

            if (i%10==0):
                logging.info ("read {0} canciones".format (i))
            # do some pre-processing and return a list of words for each review text
            yield gensim.utils.simple_preprocess (line)

# read the tokenized reviews into a list
# each review item becomes a serries of words
# so this becomes a list of lists
documents = list (read_input (data_file))
logging.info ("Done reading data file")
# Out:
# 2021-01-16 23:51:28,968 : INFO : reading file canciones.csv...this may take a while
# 2021-01-16 23:51:28,970 : INFO : read 0 canciones
# 2021-01-16 23:51:28,974 : INFO : read 10 canciones
# 2021-01-16 23:51:30,274 : INFO : read 8610 canciones
# 2021-01-16 23:51:30,275 : INFO : read 8620 canciones
# 2021-01-16 23:51:30,276 : INFO : read 8630 canciones
# 2021-01-16 23:51:30,277 : INFO : read 8640 canciones
# 2021-01-16 23:51:30,278 : INFO : read 8650 canciones
# 2021-01-16 23:51:30,279 : INFO : read 8660 canciones
# 2021-01-16 23:51:30,280 : INFO : read 8670 canciones
# 2021-01-16 23:51:30,281 : INFO : read 8680 canciones
# 2021-01-16 23:51:30,282 : INFO : read 8690 canciones
# 2021-01-16 23:51:30,282 : INFO : read 8700 canciones
# 2021-01-16 23:51:30,283 : INFO : read 8710 canciones
# 2021-01-16 23:51:30,284 : INFO : read 8720 canciones
# 2021-01-16 23:51:30,285 : INFO : read 8730 canciones
# 2021-01-16 23:51:30,286 : INFO : read 8740 canciones
# 2021-01-16 23:51:30,287 : INFO : read 8750 canciones
# 2021-01-16 23:51:30,288 : INFO : read 8760 canciones
# 2021-01-16 23:51:30,289 : INFO : read 8770 canciones
# 2021-01-16 23:51:30,290 : INFO : read 8780 canciones
# 2021-01-16 23:51:30,291 : INFO : read 8790 canciones
# 2021-01-16 23:51:30,292 : INFO : read 8800 canciones
# 2021-01-16 23:51:30,293 : INFO : read 8810 canciones
# 2021-01-16 23:51:30,294 : INFO : read 8820 canciones
# 2021-01-16 23:51:30,295 : INFO : read 8830 canciones
# 2021-01-16 23:51:30,296 : INFO : read 8840 canciones
# 2021-01-16 23:51:30,297 : INFO : read 8850 canciones
# 2021-01-16 23:51:30,298 : INFO : read 8860 canciones
# 2021-01-16 23:51:30,302 : INFO : Done reading data file

# %% [markdown]
# ## Training the Word2Vec model
#
# Training the model is fairly straightforward. You just instantiate Word2Vec and pass the reviews that we read in the previous step (the `documents`). So, we are essentially passing on a list of lists. Where each list within the main list contains a set of tokens from a user review. Word2Vec uses all these tokens to internally create a vocabulary. And by vocabulary, I mean a set of unique words.
#
# After building the vocabulary, we just need to call `train(...)` to start training the Word2Vec model. Training on the [OpinRank](http://kavita-ganesan.com/entity-ranking-data/) dataset takes about 10 minutes so please be patient while running your code on this dataset.
#
# Behind the scenes we are actually training a simple neural network with a single hidden layer. But, we are actually not going to use the neural network after training. Instead, the goal is to learn the weights of the hidden layer. These weights are essentially the word vectors that we’re trying to learn.

# %%
model = gensim.models.Word2Vec (documents, size=150, window=10, min_count=2, workers=10)
model.train(documents,total_examples=len(documents),epochs=10)
# Out:
# 2021-01-16 23:55:52,804 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2021-01-16 23:55:52,808 : INFO : collecting all words and their counts
# 2021-01-16 23:55:52,812 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-01-16 23:55:52,831 : INFO : collected 6054 word types from a corpus of 49263 raw words and 8867 sentences
# 2021-01-16 23:55:52,833 : INFO : Loading a fresh vocabulary
# 2021-01-16 23:55:52,846 : INFO : effective_min_count=2 retains 3073 unique words (50% of original 6054, drops 2981)
# 2021-01-16 23:55:52,847 : INFO : effective_min_count=2 leaves 46282 word corpus (93% of original 49263, drops 2981)
# 2021-01-16 23:55:52,862 : INFO : deleting the raw counts dictionary of 6054 items
# 2021-01-16 23:55:52,863 : INFO : sample=0.001 downsamples 54 most-common words
# 2021-01-16 23:55:52,865 : INFO : downsampling leaves estimated 34570 word corpus (74.7% of prior 46282)
# 2021-01-16 23:55:52,882 : INFO : estimated required memory for 3073 words and 150 dimensions: 5224100 bytes
# 2021-01-16 23:55:52,884 : INFO : resetting layer weights
# 2021-01-16 23:55:53,544 : INFO : training model with 10 workers on 3073 vocabulary and 150 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2021
: INFO : worker thread finished; awaiting finish of 9 more threads
# 2021-01-16 23:55:55,111 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2021-01-16 23:55:55,114 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-16 23:55:55,119 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-16 23:55:55,121 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-16 23:55:55,157 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-16 23:55:55,177 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-16 23:55:55,186 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-16 23:55:55,196 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-16 23:55:55,200 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-16 23:55:55,201 : INFO : EPOCH - 7 : training on 49263 raw words (34536 effective words) took 0.1s, 278350 effective words/s
# 2021-01-16 23:55:55,241 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2021-01-16 23:55:55,245 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2021-01-16 23:55:55,264 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-16 23:55:55,270 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-16 23:55:55,272 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-16 23:55:55,274 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-16 23:55:55,332 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-16 23:55:55,334 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-16 23:55:55,335 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-16 23:55:55,337 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-16 23:55:55,337 : INFO : EPOCH - 8 : training on 49263 raw words (34693 effective words) took 0.1s, 301967 effective words/s
# 2021-01-16 23:55:55,370 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2021-01-16 23:55:55,377 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2021-01-16 23:55:55,379 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-16 23:55:55,381 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-16 23:55:55,382 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-16 23:55:55,431 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-16 23:55:55,446 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-16 23:55:55,467 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-16 23:55:55,469 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-16 23:55:55,476 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-16 23:55:55,478 : INFO : EPOCH - 9 : training on 49263 raw words (34504 effective words) took 0.1s, 292159 effective words/s
# 2021-01-16 23:55:55,504 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2021-01-16 23:55:55,505 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2021-01-16 23:55:55,509 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-16 23:55:55,510 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-16 23:55:55,518 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-16 23:55:55,570 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-16 23:55:55,588 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-16 23:55:55,598 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-16 23:55:55,602 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-16 23:55:55,610 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-16 23:55:55,611 : INFO : EPOCH - 10 : training on 49263 raw words (34528 effective words) took 0.1s, 291912 effective words/s
# 2021-01-16 23:55:55,612 : INFO : training on a 492630 raw words (345605 effective words) took 1.4s, 245557 effective words/s
# 2021-01-16 23:55:55,613 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# (345605, 492630)

# %% [markdown]
# ## Now, let's look at some output
# This first example shows a simple case of looking up words similar to the word `dirty`. All we need to do here is to call the `most_similar` function and provide the word `dirty` as the positive example. This returns the top 10 similar words.

# %%
w1 = "pobreza"
model.wv.most_similar (positive=w1)
# Out:
# [('desigualdad', 0.9932188391685486),
#  ('injusticia', 0.9876697063446045),
#  ('libertad', 0.9875766038894653),
#  ('social', 0.9870827198028564),
#  ('explotacin', 0.9869959354400635),
#  ('confrontacin', 0.9794875979423523),
#  ('invasin', 0.9744575023651123),
#  ('clases', 0.9710953235626221),
#  ('acceso', 0.9673812389373779),
#  ('expresin', 0.964331865310669)]

# %% [markdown]
# That looks pretty good, right? Let's look at a few more. Let's look at similarity for `polite`, `france` and `shocked`.

# %%
# look up top 6 words similar to 'polite'
w1 = ["pobreza"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('desigualdad', 0.9932188391685486),
#  ('injusticia', 0.9876697063446045),
#  ('libertad', 0.9875766038894653),
#  ('social', 0.9870827198028564),
#  ('explotacin', 0.9869959354400635),
#  ('confrontacin', 0.9794875979423523)]

# %%
# look up top 6 words similar to 'france'
w1 = ["venezuela"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('grupo', 0.9631481170654297),
#  ('daniel', 0.9538662433624268),
#  ('viglietti', 0.9534628987312317),
#  ('centro', 0.9257346987724304),
#  ('soledad', 0.9225537776947021),
#  ('culpa', 0.9172824025154114)]

# %%
# look up top 6 words similar to 'shocked'
w1 = ["shocked"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('horrified', 0.80775386095047),
#  ('amazed', 0.7797470092773438),
#  ('astonished', 0.7748459577560425),
#  ('dismayed', 0.7680633068084717),
#  ('stunned', 0.7603034973144531),
#  ('appalled', 0.7466776371002197)]

# %% [markdown]
# That's, nice. You can even specify several positive examples to get things that are related in the provided context and provide negative examples to say what should not be considered as related. In the example below we are asking for all items that *relate to bed* only:

# %%
# get everything related to stuff on the bed
w1 = ["pobreza",'injusticia','explotacin']
w2 = ['opresin']
model.wv.most_similar (positive=w1,negative=w2,topn=10)
# Out:
# [('desigualdad', 0.9749658703804016),
#  ('social', 0.9687750935554504),
#  ('libertad', 0.9674961566925049),
#  ('cglro', 0.9637452960014343),
#  ('confrontacin', 0.9612442255020142),
#  ('clases', 0.9399979114532471),
#  ('invasin', 0.936730146408081),
#  ('acceso', 0.9331772327423096),
#  ('expresin', 0.9206987619400024),
#  ('infancia', 0.9137646555900574)]

# %% [markdown]
# ### Similarity between two words in the vocabulary

# %% [markdown]
# You can even use the Word2Vec model to return the similarity between two words that are present in the vocabulary.

# %%
# similarity between two different words
model.wv.similarity(w1="pobreza",w2="nacin")
# Out:
# 0.61707664

# %%
# similarity between two identical words
model.wv.similarity(w1="pobreza",w2="desigualdad")
# Out:
# 0.9932189

# %%
# similarity between two unrelated words
model.wv.similarity(w1="dirty",w2="clean")
# Out:
# 0.25355593501920781

# %% [markdown]
# Under the hood, the above three snippets computes the cosine similarity between the two specified words using word vectors of each. From the scores, it makes sense that `dirty` is highly similar to `smelly` but `dirty` is dissimilar to `clean`. If you do a similarity between two identical words, the score will be 1.0 as the range of the cosine similarity score will always be between [0.0-1.0]. You can read more about cosine similarity scoring [here](https://en.wikipedia.org/wiki/Cosine_similarity).

# %% [markdown]
# ### Find the odd one out
# You can even use Word2Vec to find odd items given a list of items.

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["cat","dog","france"])
# Out:
# 'france'

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["bed","pillow","duvet","shower"])
# Out:
# 'shower'

# %% [markdown]
# ## Understanding some of the parameters
# To train the model earlier, we had to set some parameters. Now, let's try to understand what some of them mean. For reference, this is the command that we used to train the model.
#
# ```
# model = gensim.models.Word2Vec (documents, size=150, window=10, min_count=2, workers=10)
# ```
#
# ### `size`
# The size of the dense vector to represent each token or word. If you have very limited data, then size should be a much smaller value. If you have lots of data, its good to experiment with various sizes. A value of 100-150 has worked well for me.
#
# ### `window`
# The maximum distance between the target word and its neighboring word. If your neighbor's position is greater than the maximum window width to the left and the right, then, some neighbors are not considered as being related to the target word. In theory, a smaller window should give you terms that are more related. If you have lots of data, then the window size should not matter too much, as long as its a decent sized window.
#
# ### `min_count`
# Minimium frequency count of words. The model would ignore words that do not statisfy the `min_count`. Extremely infrequent words are usually unimportant, so its best to get rid of those. Unless your dataset is really tiny, this does not really affect the model.
#
# ### `workers`
# How many threads to use behind the scenes?

# %% [markdown]
# ## When should you use Word2Vec?
#
# There are many application scenarios for Word2Vec. Imagine if you need to build a sentiment lexicon. Training a Word2Vec model on large amounts of user reviews helps you achieve that. You have a lexicon for not just sentiment, but for most words in the vocabulary.
#
# Beyond, raw unstructured text data, you could also use Word2Vec for more structured data. For example, if you had tags for a million stackoverflow questions and answers, you could find tags that are related to a given tag and recommend the related ones for exploration. You can do this by treating each set of co-occuring tags as a "sentence" and train a Word2Vec model on this data. Granted, you still need a large number of examples to make it work.
